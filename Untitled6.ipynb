# %% [markdown]
# <a href="https://colab.research.google.com/github/BenFarz/Demo/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.8.2'

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
X = tf.range(-100, 100, 4)
y = X+7
X,y
# Out:
# (<tf.Tensor: shape=(50,), dtype=int32, numpy=
#  array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#          -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#          -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#           32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#           76,   80,   84,   88,   92,   96], dtype=int32)>,
#  <tf.Tensor: shape=(50,), dtype=int32, numpy=
#  array([-93, -89, -85, -81, -77, -73, -69, -65, -61, -57, -53, -49, -45,
#         -41, -37, -33, -29, -25, -21, -17, -13,  -9,  -5,  -1,   3,   7,
#          11,  15,  19,  23,  27,  31,  35,  39,  43,  47,  51,  55,  59,
#          63,  67,  71,  75,  79,  83,  87,  91,  95,  99, 103], dtype=int32)>)

# %%
X = tf.expand_dims(X, axis =-1)
y = tf.expand_dims(y, axis = -1)

# %%
X_train = X[:40]
y_train = y[:40]
X_test = X[40:]
y_test = y[40:]

# %%
plt.figure(figsize = (10,7))
plt.scatter(X_train, y_train, c="b", label=["train"])
plt.scatter(X_test, y_test, c="g", label="True_data")
plt.legend()

# %%
tf.random.set_seed(43)
model_1 =tf.keras. Sequential([
    tf.keras.layers.Dense(1, input_shape = [1])
])
model_1.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=["mae"])
model_1.fit(X_train, y_train, epochs= 100, verbose = 1)
y_pred1 = model_1.predict(X_test)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 8ms/step - loss: 71.1615 - mae: 71.1615
# Epoch 2/100
# 2/2 [==============================] - 0s 10ms/step - loss: 33.5040 - mae: 33.5040
# Epoch 3/100
# 2/2 [==============================] - 0s 10ms/step - loss: 6.6085 - mae: 6.6085
# Epoch 4/100
# 2/2 [==============================] - 0s 8ms/step - loss: 8.4689 - mae: 8.4689
# Epoch 5/100
# 2/2 [==============================] - 0s 11ms/step - loss: 8.8385 - mae: 8.8385
# Epoch 6/100
# 2/2 [==============================] - 0s 8ms/step - loss: 7.2347 - mae: 7.2347
# Epoch 7/100
# 2/2 [==============================] - 0s 10ms/step - loss: 8.2397 - mae: 8.2397
# Epoch 8/100
# 2/2 [==============================] - 0s 6ms/step - loss: 13.6352 - mae: 13.6352
# Epoch 9/100
# 2/2 [==============================] - 0s 7ms/step - loss: 5.9385 - mae: 5.9385
# Epoch 10/100
# 2/2 [==============================] - 0s 7ms/step - loss: 7.0204 - mae: 7.0204
# Epoch 11/100
# ...

# %%
tf.random.set_seed(43)
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(1, input_shape=[1])
])
model_2.compile(loss = tf.keras.losses.mae,
                optimizer = tf.keras.optimizers.SGD(),
                metrics=["mae"])
model_2.fit(X_train, y_train, epochs = 100, verbose = 1)
y_pred2 = model_2.predict(X_test)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 11ms/step - loss: 39.1235 - mae: 39.1235
# Epoch 2/100
# 2/2 [==============================] - 0s 7ms/step - loss: 36.6322 - mae: 36.6322
# Epoch 3/100
# 2/2 [==============================] - 0s 11ms/step - loss: 45.7750 - mae: 45.7750
# Epoch 4/100
# 2/2 [==============================] - 0s 12ms/step - loss: 10.4039 - mae: 10.4039
# Epoch 5/100
# 2/2 [==============================] - 0s 7ms/step - loss: 5.3016 - mae: 5.3016
# Epoch 6/100
# 2/2 [==============================] - 0s 6ms/step - loss: 10.1930 - mae: 10.1930
# Epoch 7/100
# 2/2 [==============================] - 0s 8ms/step - loss: 17.0815 - mae: 17.0815
# Epoch 8/100
# 2/2 [==============================] - 0s 6ms/step - loss: 22.8127 - mae: 22.8127
# Epoch 9/100
# 2/2 [==============================] - 0s 5ms/step - loss: 22.2632 - mae: 22.2632
# Epoch 10/100
# 2/2 [==============================] - 0s 6ms/step - loss: 12.0991 - mae: 12.0991
# Epoch 11/100
# ...

# %%
tf.random.set_seed(43)
model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(1, input_shape = [1])
])
model_3.compile(loss = tf.keras.losses.mae,
                optimizer = tf.keras.optimizers.SGD(),
                metrics=["mae"])
model_3.fit(X_train, y_train, epochs = 500, verbose = 1)
y_pred3 = model_3.predict(X_test)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 0s 6ms/step - loss: 39.1235 - mae: 39.1235
# Epoch 2/500
# 2/2 [==============================] - 0s 5ms/step - loss: 36.6322 - mae: 36.6322
# Epoch 3/500
# 2/2 [==============================] - 0s 4ms/step - loss: 45.7750 - mae: 45.7750
# Epoch 4/500
# 2/2 [==============================] - 0s 4ms/step - loss: 10.4039 - mae: 10.4039
# Epoch 5/500
# 2/2 [==============================] - 0s 4ms/step - loss: 5.3016 - mae: 5.3016
# Epoch 6/500
# 2/2 [==============================] - 0s 6ms/step - loss: 10.1930 - mae: 10.1930
# Epoch 7/500
# 2/2 [==============================] - 0s 4ms/step - loss: 17.0815 - mae: 17.0815
# Epoch 8/500
# 2/2 [==============================] - 0s 6ms/step - loss: 22.8127 - mae: 22.8127
# Epoch 9/500
# 2/2 [==============================] - 0s 4ms/step - loss: 22.2632 - mae: 22.2632
# Epoch 10/500
# 2/2 [==============================] - 0s 11ms/step - loss: 12.0991 - mae: 12.0991
# Epoch 11/500
# ...

# %%
model_1.summary(),
model_2.summary(),
model_3.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_16 (Dense)            (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_17 (Dense)            (None, 100)               200
#
#  dense_18 (Dense)            (None, 1)                 101
#
# ...
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_19 (Dense)            (None, 100)               200
#
# ...

# %%
y_pred1 = model_1.predict(X_test)
y_pred1
# Out:
# array([[ 64.856514],
#        [ 69.11032 ],
#        [ 73.36413 ],
#        [ 77.617935],
#        [ 81.87175 ],
#        [ 86.12556 ],
#        [ 90.379364],
#        [ 94.63318 ],
#        [ 98.886986],
#        [103.14079 ]], dtype=float32)

# %%
#import matplotlib.pyplot as plt
def plot_predictions(train_data = X_train,
                     train_labels = y_train,
                     test_data = X_test,
                     test_labels = y_test,
                     predictions = y_pred1):
# Out:
#   File "<ipython-input-45-2c8a3be66a7b>", line 6
#     predictions = y_pred1):
#                            ^
# SyntaxError: unexpected EOF while parsing

# %%
plt.figure(figsize = (10,7))
plt.scatter(train_data, train_labels, c="b", labels="TrainOne")
plt.scatter(test_data, test_labels, c="g", labels="TrueOne")
plt.scatter(test_data, predictions, c="r", labels="PredOne")
plt.legend();
plot_predictions()

# %%
y_pred1,
y_pred2,
y_pred3
# Out:
# array([[54.642242],
#        [58.00789 ],
#        [61.373535],
#        [64.73918 ],
#        [68.10483 ],
#        [71.47047 ],
#        [74.83611 ],
#        [78.20176 ],
#        [81.5674  ],
#        [84.93304 ]], dtype=float32)

# %%
def plot_predictions(train_data=X_train, 
                     train_labels=y_train, 
                     test_data=X_test, 
                     test_labels=y_test, 
                     predictions=y_pred1):
  """
  Plots training data, test data and compares predictions.
  """
  plt.figure(figsize=(10, 7))
  # Plot training data in blue
  plt.scatter(train_data, train_labels, c="b", label="Training data")
  # Plot test data in green
  plt.scatter(test_data, test_labels, c="g", label="Testing data")
  # Plot the predictions in red (predictions were made on the test data)
  plt.scatter(test_data, predictions, c="r", label="Predictions")
  # Show the legend
  plt.legend();
