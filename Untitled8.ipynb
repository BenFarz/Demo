# %% [markdown]
# <a href="https://colab.research.google.com/github/BenFarz/Demo/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.8.2'

# %%
import numpy as np

# %%
X = tf.range(-100, 100, 4)
y=X+10

# %%
X=tf.expand_dims(X, axis=-1)
y=tf.expand_dims(y, axis = -1)

# %%
X_train = X[:40]
y_train = y[:40]
X_test = X[40:]
y_test  = y[40:]

# %%
tf.shape(X)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([50,  1], dtype=int32)>

# %%
tf.random.set_seed(42)
model1 = tf.keras.Sequential([
                          tf.keras.layers.Dense(1)
                          ])
model1.compile(loss=tf.keras.losses.mae,
               optimizer=tf.keras.optimizers.SGD(),
               metrics=["mae"])
model1.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 5ms/step - loss: 15.9024 - mae: 15.9024
# Epoch 2/100
# 2/2 [==============================] - 0s 4ms/step - loss: 11.2837 - mae: 11.2837
# Epoch 3/100
# 2/2 [==============================] - 0s 2ms/step - loss: 11.1074 - mae: 11.1074
# Epoch 4/100
# 2/2 [==============================] - 0s 2ms/step - loss: 9.2991 - mae: 9.2991
# Epoch 5/100
# 2/2 [==============================] - 0s 3ms/step - loss: 10.1677 - mae: 10.1677
# Epoch 6/100
# 2/2 [==============================] - 0s 3ms/step - loss: 9.4303 - mae: 9.4303
# Epoch 7/100
# 2/2 [==============================] - 0s 3ms/step - loss: 8.5704 - mae: 8.5704
# Epoch 8/100
# 2/2 [==============================] - 0s 3ms/step - loss: 9.0442 - mae: 9.0442
# Epoch 9/100
# 2/2 [==============================] - 0s 3ms/step - loss: 18.7517 - mae: 18.7517
# Epoch 10/100
# 2/2 [==============================] - 0s 3ms/step - loss: 10.1142 - mae: 10.1142
# Epoch 11/100
# ...

# %%
tf.random.set_seed(42)
model2=tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(1)
])
model2.compile(loss=tf.keras.losses.mae,
               optimizer=tf.keras.optimizers.SGD(),
               metrics=["mae"])
model2.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 4ms/step - loss: 36.0963 - mae: 36.0963
# Epoch 2/100
# 2/2 [==============================] - 0s 5ms/step - loss: 28.7401 - mae: 28.7401
# Epoch 3/100
# 2/2 [==============================] - 0s 4ms/step - loss: 33.2070 - mae: 33.2070
# Epoch 4/100
# 2/2 [==============================] - 0s 3ms/step - loss: 30.5341 - mae: 30.5341
# Epoch 5/100
# 2/2 [==============================] - 0s 3ms/step - loss: 15.5504 - mae: 15.5504
# Epoch 6/100
# 2/2 [==============================] - 0s 12ms/step - loss: 12.3355 - mae: 12.3355
# Epoch 7/100
# 2/2 [==============================] - 0s 3ms/step - loss: 11.6147 - mae: 11.6147
# Epoch 8/100
# 2/2 [==============================] - 0s 3ms/step - loss: 11.2547 - mae: 11.2547
# Epoch 9/100
# 2/2 [==============================] - 0s 6ms/step - loss: 42.3778 - mae: 42.3778
# Epoch 10/100
# 2/2 [==============================] - 0s 8ms/step - loss: 29.5266 - mae: 29.5266
# Epoch 11/100
# ...

# %%
tf.random.set_seed(42)
model3 = tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(1)
])
model3.compile(loss=tf.keras.losses.mae,
               optimizer=tf.keras.optimizers.SGD(),
               metrics=["mae"])
model3.fit(X_train, y_train, epochs=500)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 0s 4ms/step - loss: 36.0963 - mae: 36.0963
# Epoch 2/500
# 2/2 [==============================] - 0s 5ms/step - loss: 28.7401 - mae: 28.7401
# Epoch 3/500
# 2/2 [==============================] - 0s 3ms/step - loss: 33.2070 - mae: 33.2070
# Epoch 4/500
# 2/2 [==============================] - 0s 5ms/step - loss: 30.5341 - mae: 30.5341
# Epoch 5/500
# 2/2 [==============================] - 0s 2ms/step - loss: 15.5504 - mae: 15.5504
# Epoch 6/500
# 2/2 [==============================] - 0s 6ms/step - loss: 12.3355 - mae: 12.3355
# Epoch 7/500
# 2/2 [==============================] - 0s 4ms/step - loss: 11.6147 - mae: 11.6147
# Epoch 8/500
# 2/2 [==============================] - 0s 5ms/step - loss: 11.2547 - mae: 11.2547
# Epoch 9/500
# 2/2 [==============================] - 0s 4ms/step - loss: 42.3778 - mae: 42.3778
# Epoch 10/500
# 2/2 [==============================] - 0s 5ms/step - loss: 29.5266 - mae: 29.5266
# Epoch 11/500
# ...

# %%
y_pred1 = model1.predict(X_test)
y_pred2 = model2.predict(X_test)
y_pred3 = model3.predict(X_test)

print(y_pred1, "\n",
      y_pred2, "\n",
      y_pred3)
# Out:
# [[53.57109 ]
#  [57.05633 ]
#  [60.541573]
#  [64.02681 ]
#  [67.512054]
#  [70.99729 ]
#  [74.48254 ]
#  [77.96777 ]
#  [81.45301 ]
#  [84.938255]]
#  [[ 76.422066]
#  [ 81.40026 ]
#  [ 86.378456]
#  [ 91.35665 ]
#  [ 96.334854]
#  [101.31305 ]
#  [106.29124 ]
#  [111.26945 ]
#  [116.247635]
#  [121.22584 ]]
#  [[17.023079]
#  [17.858135]
#  [18.693192]
#  [19.52825 ]
#  [20.363306]
#  [21.198362]
#  [22.033419]
#  [22.868475]
#  [23.703531]
#  [24.53859 ]]

# %%
from tensorflow.keras.utils import plot_model
#plot_model(model = model1, show_shapes = "True"),
#plot_model(model = model2, show_shapes = "True"),
plot_model(model = model3, show_shapes = "True")

# %%
plot_model(model = model2, show_shapes = "True")

# %%
plot_model(model = model1 , show_shapes = "True")

# %%
import matplotlib.pyplot as plt

# %%
X_test,X_train
# Out:
# (<tf.Tensor: shape=(10, 1), dtype=int32, numpy=
#  array([[60],
#         [64],
#         [68],
#         [72],
#         [76],
#         [80],
#         [84],
#         [88],
#         [92],
#         [96]], dtype=int32)>, <tf.Tensor: shape=(40, 1), dtype=int32, numpy=
#  array([[-100],
#         [ -96],
#         [ -92],
#         [ -88],
#         [ -84],
#         [ -80],
#         [ -76],
#         [ -72],
#         [ -68],
#         [ -64],
#         [ -60],
#         [ -56],
#         [ -52],
#         [ -48],
#         [ -44],
#         [ -40],
#         [ -36],
#         [ -32],
#         [ -28],
#         [ -24],
#         [ -20],
#         [ -16],
#         [ -12],
#         [  -8],
#         [  -4],
#         [   0],
#         [   4],
#         [   8],
#         [  12],
#         [  16],
#         [  20],
#         [  24],
#         [  28],
#         [  32],
#         [  36],
#         [  40],
#         [  44],
#         [  48],
#         [  52],
# ...

# %%
def plot_predictions(train_data = X_train,
  train_labels = y_train,
  test_data =X_test,
  test_labels =y_test,
  predictions1 = y_pred1,
  predictions2 = y_pred2,
  predictions3 = y_pred3):
#plt.figure(figsize = (10,7))
  plt.scatter(train_data, train_labels, c="b", label= "train")
  plt.scatter(test_data, test_labels, c="g", label="test" )
  plt.scatter(test_data, predictions1, c="c", label="P1")
  plt.scatter(test_data, predictions2, c="r", label="P2")
  plt.scatter(test_data, predictions3, c="k", label="P3")
  plt.legend();

# %%
plt.figure(figsize=(10,7))
plot_predictions()

# %%
model1.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 86ms/step - loss: 18.7453 - mae: 18.7453
# [18.74532699584961, 18.74532699584961]

# %%
model2.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 72ms/step - loss: 10.8239 - mae: 10.8239
# [10.823949813842773, 10.823949813842773]

# %%
model3.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 63ms/step - loss: 67.2192 - mae: 67.2192
# [67.21916198730469, 67.21916198730469]

# %%
mae = tf.metrics.mean_absolute_error(tf.squeeze(X_test), tf.squeeze(y_test))
mae
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=10>

# %%
mae1 =tf.metrics.mean_absolute_error(tf.squeeze(X_test), tf.squeeze(y_pred1))
mae1
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=8.745328>

# %%
mae2 = tf.metrics.mean_absolute_error(tf.squeeze(X_test), tf.squeeze(y_pred2))
mae2
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=20.82395>

# %%
mae3 = tf.metrics.mean_absolute_error(tf.squeeze(X_test), tf.squeeze(y_pred3))
mae3
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=57.219166>

# %%
def mse(O, M):
  return tf.metrics.mean_squared_error(O, M)

# %%
mse(tf.squeeze(y_test), tf.squeeze(y_pred2))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=125.05205>

# %%
def mae(y_true , y_pred):
  return tf.metrics.mean_absolute_error(y_true = tf.squeeze(y_test) , y_pred = tf.squeeze(y_pred1) )

# %%
mae(y_test, y_pred1)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=18.745327>

# %%
mae(X_test, y_test)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=18.745327>
